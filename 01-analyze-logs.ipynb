# %% [markdown]
# # White House visitor logs

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import datetime as dt
import altair as alt
import numpy as np

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
pd.options.display.max_colwidth = None

# %% [markdown]
# ### Data dictionary

# %%
# "https://obamawhitehouse.archives.gov/files/disclosures/visitors/WhiteHouse-WAVES-Key-1209.txt"

# %%
today = dt.date.today().strftime("%m-%d-%Y")

# %%
df = pd.read_csv(
    "data/processed/log_latest.csv",
    parse_dates=[
        "appt_made_date",
        "appt_start_date",
        "appt_end_date",
        "appt_cancel_date",
        "releasedate",
    ],
)

# %%
df.sort_values(["appt_made_date"], ascending=False).head()
# Out:
#      namelast  namefirst namemid     uin  bdgnbr access_type  toa  poa  tod  \
# 4868  HARKINS  CHRISTINE       P  U36027     NaN          VA  NAN  NAN  NAN
# 7944   PETERS      KATIE       J  U36004     NaN          VA  NAN  NAN  NAN
# 7943   JAVAID      ZAINA       N  U36004     NaN          VA  NAN  NAN  NAN
# 7942    CREWS     ARLENE       N  U36004     NaN          VA  NAN  NAN  NAN
# 5360   SINGLA      RUKKU       N  U36004     NaN          VA  NAN  NAN  NAN
#
#       pod      appt_made_date     appt_start_date       appt_end_date  \
# 4868  NAN 2021-11-30 11:57:00 2021-11-30 14:00:00 2021-11-30 23:59:00
# 7944  NAN 2021-11-30 09:26:00 2021-11-30 12:00:00 2021-11-30 23:59:00
# 7943  NAN 2021-11-30 09:26:00 2021-11-30 12:00:00 2021-11-30 23:59:00
# 7942  NAN 2021-11-30 09:26:00 2021-11-30 12:00:00 2021-11-30 23:59:00
# 5360  NAN 2021-11-30 09:26:00 2021-11-30 12:00:00 2021-11-30 23:59:00
#
#      appt_cancel_date  total_people last_updatedby post     lastentrydate  \
# 4868              NaT           1.0             DN  WIN  11/30/2021 11:57
# 7944              NaT           5.0             KG  WIN   11/30/2021 9:26
# 7943              NaT           5.0             KG  WIN   11/30/2021 9:26
# 7942              NaT           5.0             KG  WIN   11/30/2021 9:26
# 5360              NaT           5.0             KG  WIN   11/30/2021 9:26
#
#      terminal_suffix visitee_namelast visitee_namefirst meeting_loc  \
# 4868              DN           NELSON             DAVID         VPR
# 7944              KG              NAN         PLAYMAKER         VPR
# 7943              KG              NAN         PLAYMAKER         VPR
# 7942              KG              NAN         PLAYMAKER         VPR
# 5360              KG              NAN         PLAYMAKER         VPR
#
#      meeting_room caller_name_last caller_name_first  caller_room releasedate  \
# 4868          VPR           NELSON             DAVID          NaN  2022-03-11
# 7944    RESIDENCE          GOODHUE             KEVIN          NaN  2022-03-11
# 7943    RESIDENCE          GOODHUE             KEVIN          NaN  2022-03-11
# 7942    RESIDENCE          GOODHUE             KEVIN          NaN  2022-03-11
# 5360    RESIDENCE          GOODHUE             KEVIN          NaN  2022-03-11
#
#      description
# 4868         NAN
# 7944         NAN
# 7943         NAN
# 7942         NAN
# 5360         NAN

# %% [markdown]
# ### Buildings

# %%
df.meeting_loc.value_counts()
# Out:
# OEOB    12255
# WH      10483
# NEOB     1255
# VPR      1102
# EEOB      837
# NAN       737
# Name: meeting_loc, dtype: int64

# %% [markdown]
# ### Rooms

# %%
df.meeting_room.value_counts().head()
# Out:
# SOUTH LAWN    1976
# RES - STAT    1479
# EW206         1220
# 445           1063
# 374           1011
# Name: meeting_room, dtype: int64

# %% [markdown]
# ### Who's visited the Oval?

# %%
len(df[df["meeting_room"].str.contains("OVAL")])
# Out:
# 478

# %%
df[df["meeting_room"].str.contains("OVAL")].head()
# Out:
#             namelast namefirst namemid     uin    bdgnbr access_type  \
# 170           FAUVRE       LEO       B  U24904       NaN          VA
# 181            SMITH     GAYLE       E  U24948       NaN          VA
# 185  LATTHIVONGSKORN   JIRAYUT       N  U24901  179726.0          VA
# 189     PRAELIANGULO     MARIA       N  U24901  178274.0          VA
# 190      RANGELPEREZ     LEYDY       M  U24901  178054.0          VA
#
#                  toa    poa              tod  pod      appt_made_date  \
# 170  5/14/2021 10:47  B0401              NAN  NAN 2021-05-13 10:33:00
# 181              NAN    NAN              NAN  NAN 2021-05-14 07:02:00
# 185  5/14/2021 13:24  B0401  5/14/2021 17:20  A05 2021-05-13 09:05:00
# 189  5/14/2021 13:21  B0401  5/14/2021 17:20  A05 2021-05-13 09:05:00
# 190  5/14/2021 13:21  B0401              NAN  NAN 2021-05-13 09:05:00
#
#         appt_start_date       appt_end_date appt_cancel_date  total_people  \
# 170 2021-05-14 10:30:00 2021-05-14 23:59:00              NaT           4.0
# 181 2021-05-14 12:45:00 2021-05-14 23:59:00              NaT           1.0
# 185 2021-05-14 13:00:00 2021-05-14 23:59:00              NaT           7.0
# 189 2021-05-14 13:00:00 2021-05-14 23:59:00              NaT           7.0
# 190 2021-05-14 13:00:00 2021-05-14 23:59:00              NaT           7.0
#
#     last_updatedby post    lastentrydate terminal_suffix visitee_namelast  \
# 170             PS  WIN  5/13/2021 10:33              PS              NAN
# 181             AW  WIN   5/14/2021 7:02              AW              NAN
# 185             NS  WIN   5/13/2021 9:05              NS              NAN
# 189             NS  WIN   5/13/2021 9:05              NS              NAN
# 190             NS  WIN   5/13/2021 9:05              NS              NAN
#
#     visitee_namefirst meeting_loc meeting_room caller_name_last  \
# 170             POTUS          WH   OVAL OFFIC            SINGH
# 181             POTUS          WH         OVAL          WITHERS
# 185             POTUS          WH   OVAL OFFIC            SILVA
# 189             POTUS          WH   OVAL OFFIC            SILVA
# 190             POTUS          WH   OVAL OFFIC            SILVA
#
#     caller_name_first  caller_room releasedate description
# 170             PRIYA          NaN  2021-08-30         NAN
# 181              ANNE          NaN  2021-08-30         NAN
# 185             NEZLY          NaN  2021-08-30         NAN
# 189             NEZLY          NaN  2021-08-30         NAN
# 190             NEZLY          NaN  2021-08-30         NAN

# %% [markdown]
# ### Where meeting room is ...

# %%
df[df["meeting_room"].str.contains("EW206")].head()
# Out:
#     namelast namefirst namemid     uin  bdgnbr access_type  toa  poa  tod  \
# 338  MACKALL       LEE       A  U25238     NaN          VA  NAN  NAN  NAN
# 339  MAHONEY    ROBERT       P  U25238     NaN          VA  NAN  NAN  NAN
# 340  MASLINE   XAVIERA       J  U25238     NaN          VA  NAN  NAN  NAN
# 341    MAXON      ERIC       D  U25238     NaN          VA  NAN  NAN  NAN
# 343   ORTMAN    JUSTIN       D  U25238     NaN          VA  NAN  NAN  NAN
#
#      pod      appt_made_date     appt_start_date       appt_end_date  \
# 338  NAN 2021-05-20 13:00:00 2021-05-21 10:00:00 2021-05-21 23:59:00
# 339  NAN 2021-05-20 13:00:00 2021-05-21 10:00:00 2021-05-21 23:59:00
# 340  NAN 2021-05-20 09:06:00 2021-05-21 10:00:00 2021-05-21 23:59:00
# 341  NAN 2021-05-20 09:06:00 2021-05-21 10:00:00 2021-05-21 23:59:00
# 343  NAN 2021-05-20 09:06:00 2021-05-21 10:00:00 2021-05-21 23:59:00
#
#     appt_cancel_date  total_people last_updatedby post    lastentrydate  \
# 338              NaT          31.0             DV  WIN  5/20/2021 13:00
# 339              NaT          31.0             DV  WIN  5/20/2021 13:00
# 340              NaT          31.0             DV  WIN   5/20/2021 9:06
# 341              NaT          31.0             DV  WIN   5/20/2021 9:06
# 343              NaT          31.0             DV  WIN   5/20/2021 9:06
#
#     terminal_suffix visitee_namelast visitee_namefirst meeting_loc  \
# 338              DV              NAN             POTUS          WH
# 339              DV              NAN             POTUS          WH
# 340              DV              NAN             POTUS          WH
# 341              DV              NAN             POTUS          WH
# 343              DV              NAN             POTUS          WH
#
#     meeting_room caller_name_last caller_name_first  caller_room releasedate  \
# 338        EW206              VIA            DANIEL          NaN  2021-08-30
# 339        EW206              VIA            DANIEL          NaN  2021-08-30
# 340        EW206              VIA            DANIEL          NaN  2021-08-30
# 341        EW206              VIA            DANIEL          NaN  2021-08-30
# 343        EW206              VIA            DANIEL          NaN  2021-08-30
#
#     description
# 338         NAN
# 339         NAN
# 340         NAN
# 341         NAN
# 343         NAN

# %% [markdown]
# ### Where 'visitee' is explicity the Vice President

# %%
len(df[df["visitee_namefirst"].str.contains("VPOTUS")])
# Out:
# 131

# %%
df[df["visitee_namefirst"].str.contains("VPOTUS")].to_csv(
    "data/processed/vpotus_visitee.csv", index=False
)
